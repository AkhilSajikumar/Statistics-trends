# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#read the csv file into a Dataframe
datas=pd.read_csv('Song.csv')

# %%
#Display all rows of DataFrame
datas
# Out:
#                        Artist                              Title  Year  \
# 0     Bill Haley & his Comets              Rock Around the Clock  1955
# 1                 Celine Dion                My Heart Will Go On  1998
# 2             Sinead O'Connor               Nothing Compares 2 U  1990
# 3                 The Beatles                           Hey Jude  1968
# 4                 Bryan Adams  (Everything I Do) I Do it For You  1991
# ...                       ...                                ...   ...
# 4845                  Rihanna       If It's Lovin' That You Want  2005
# 4846                Al Jolson                          All Alone  1925
# 4847                   Sailor                Girls, Girls, Girls  1976
# 4848             Inner Circle                  Games People Play  1994
# 4849                  The Who                    See Me, Feel Me  1970
#
#        Sales  Streams  Downloads  Radio Plays  Rating
# 0     36.503   19.961      7.458        5.663   0.760
# ...

# %%
#Checking null values
datas.isnull().sum()
# Out:
# Artist         0
# Title          0
# Year           0
# Sales          0
# Streams        0
# Downloads      0
# Radio Plays    0
# Rating         0
# dtype: int64

# %%
#Checking duplicate values
datas[datas.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Artist, Title, Year, Sales, Streams, Downloads, Radio Plays, Rating]
# Index: []

# %%
#Displaying basic staticstical functions
datas.describe()
# Out:
#               Year        Sales      Streams    Downloads  Radio Plays  \
# count  4850.000000  4850.000000  4850.000000  4850.000000  4850.000000
# mean   1979.861443     8.154870     4.628823     2.970114     3.985120
# std      19.759676     4.555715     3.273776     2.668744     4.354419
# min    1901.000000     4.149000     0.000000     0.000000     0.000000
# 25%    1967.000000     5.069250     2.351250     1.039500     0.600000
# 50%    1981.000000     6.438000     4.200000     2.200000     2.570000
# 75%    1996.000000     9.784000     6.307000     4.183750     5.884000
# max    2014.000000    36.503000    25.545000    19.780000    24.393000
#
#             Rating
# count  4850.000000
# mean      0.481876
# std       0.624719
# min       0.000000
# 25%       0.000000
# 50%       0.512000
# 75%       0.571000
# max       4.460000

# %%
#Reducing the data to 80 rows
trend_song=datas.iloc[0:80,0:10]

# %%
#Displaying all data's in 80 rows
trend_song
# Out:
#                      Artist                                     Title  Year  \
# 0   Bill Haley & his Comets                     Rock Around the Clock  1955
# 1               Celine Dion                       My Heart Will Go On  1998
# 2           Sinead O'Connor                      Nothing Compares 2 U  1990
# 3               The Beatles                                  Hey Jude  1968
# 4               Bryan Adams         (Everything I Do) I Do it For You  1991
# ..                      ...                                       ...   ...
# 75                Doris Day  Que sera sera (Whatever will be will be)  1956
# 76        Flo-Rida & T-Pain                                       Low  2008
# 77            Nat King Cole                                 Mona Lisa  1950
# 78              Terry Jacks                        Seasons in the Sun  1974
# 79             Culture Club                           Karma Chameleon  1983
#
#      Sales  Streams  Downloads  Radio Plays  Rating
# ...

# %%
#Creating a new figure with size 12, 12
plt.figure(figsize=(12, 12))
#plot a bar chart where the X axis represent Artist anf Y axis represent Rating
plt.bar(trend_song['Artist'],trend_song['Rating'])
plt.xlabel("Artist")
plt.ylabel("Rating")
plt.xticks(rotation=90, fontsize=8)
plt.title("Artist V/S Rating")
#Display the plot
plt.show()

# %%
#Create a scatter plot with sales and streams
plt.scatter(trend_song["Sales"], trend_song["Streams"])
plt.xlabel("Sales")
plt.ylabel("Streams")
plt.title("Relation between Sales and Streams")
plt.show()

# %%
trend_song
# Out:
#                      Artist                                     Title  Year  \
# 0   Bill Haley & his Comets                     Rock Around the Clock  1955
# 1               Celine Dion                       My Heart Will Go On  1998
# 2           Sinead O'Connor                      Nothing Compares 2 U  1990
# 3               The Beatles                                  Hey Jude  1968
# 4               Bryan Adams         (Everything I Do) I Do it For You  1991
# ..                      ...                                       ...   ...
# 75                Doris Day  Que sera sera (Whatever will be will be)  1956
# 76        Flo-Rida & T-Pain                                       Low  2008
# 77            Nat King Cole                                 Mona Lisa  1950
# 78              Terry Jacks                        Seasons in the Sun  1974
# 79             Culture Club                           Karma Chameleon  1983
#
#      Sales  Streams  Downloads  Radio Plays  Rating
# ...

# %%
#Checking the correlation
trend=trend_song[['Year', 'Sales', 'Streams', 'Downloads', 'Radio Plays', 'Rating'] ].corr()
trend
# Out:
#                  Year     Sales   Streams  Downloads  Radio Plays    Rating
# Year         1.000000  0.050349 -0.548649  -0.044946     0.545421  0.505922
# Sales        0.050349  1.000000  0.464412   0.220093     0.374650  0.366099
# Streams     -0.548649  0.464412  1.000000   0.036114    -0.422165 -0.198152
# Downloads   -0.044946  0.220093  0.036114   1.000000     0.342585 -0.135789
# Radio Plays  0.545421  0.374650 -0.422165   0.342585     1.000000  0.437333
# Rating       0.505922  0.366099 -0.198152  -0.135789     0.437333  1.000000

# %%
#Calculating the median for song's Rating
medians=trend_song['Rating'].median()
medians
# Out:
# 1.0745

# %%
#Calculating standard deviation for sales
Standard_deviation=trend_song['Sales'].std()
Standard_deviation
# Out:
# 3.354938492427943

# %%
#Calculating skew value of streams
skew=trend_song['Streams'].skew()
skew
# Out:
# 0.7909687955616238

# %%
#Calculating kurtosis of downloads
Kurtosis=trend_song["Downloads"].kurtosis()
Kurtosis
# Out:
# 0.2511093379964082

# %%
#Creating the correlation matrix
plt.figure(dpi=144)
numeri_c=datas.apply(pd.to_numeric, errors='coerce')
plt.figure(figsize=(20, 20))
plt.title('correlation matrix', fontsize=25)
sns.heatmap(trend, cmap='RdBu', annot=True)
plt.title("Relation",size=20)
plt.show()
